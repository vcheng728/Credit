# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

test = pd.read_csv("./cs-test.csv",index_col = 0)
train = pd.read_csv('./cs-training.csv',index_col = 0)
sample = pd.read_csv('./sampleEntry.csv')

# %%
# can see only monthlyincome and dependents have missing values, will probably impute with 0
train.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295207
# std            0.249746                            249.755371      14.771866
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.202690e+05
# mean                               0.421033     353.005076   6.670221e+03
# ...

# %%
# can see only monthlyincome and dependents have missing values, will probably impute with 0
test.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count               0.0                         101503.000000  101503.000000
# mean                NaN                              5.310000      52.405436
# std                 NaN                            196.156039      14.779756
# min                 NaN                              0.000000      21.000000
# 25%                 NaN                              0.030131      41.000000
# 50%                 NaN                              0.152586      52.000000
# 75%                 NaN                              0.564225      63.000000
# max                 NaN                          21821.000000     104.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         101503.000000  101503.000000   8.140000e+04
# mean                               0.453770     344.475020   6.855036e+03
# ...

# %%
stackt = pd.concat([test,train], keys=['test', 'train'])
stackt[(stackt['MonthlyIncome']<200) 
#        & (stackt['MonthlyIncome']<300)
      ]
# Out:
#               SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# test  7                    NaN                              0.587778   50
#       10                   NaN                              1.000000   23
#       135                  NaN                              0.176630   67
#       237                  NaN                              1.098821   76
#       308                  NaN                              1.000000   22
#       325                  NaN                              0.733150   36
#       367                  NaN                              0.379727   34
#       424                  NaN                              0.000000   78
#       627                  NaN                              0.977525   29
#       679                  NaN                              0.359228   51
#       808                  NaN                              1.000000   21
#       856                  NaN                              0.452581   47
# ...

# %%
#we see that for the entries with no MonthlyIncome, 
# if theres no monthly income and debt ratio > 100, make monthly income = debt ratio
# debt ratio to be np.mean(stackt[stackt['MonthlyIncome'].notnull()]['DebtRatio'])
stackt[stackt['MonthlyIncome'].isna()].describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines           age  \
# count      29731.000000                          49834.000000  49834.000000
# mean           0.056137                              6.414190     56.494582
# std            0.230189                            218.592754     15.462998
# min            0.000000                              0.000000     21.000000
# 25%            0.000000                              0.015859     46.000000
# 50%            0.000000                              0.081191     57.000000
# 75%            0.000000                              0.439414     67.000000
# max            1.000000                          22198.000000    109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                          49834.000000   49834.000000            0.0
# mean                               0.616306    1652.894831            NaN
# ...

# %%
stackt[(stackt['MonthlyIncome'].notnull()) & (stackt['MonthlyIncome'] > 100)].describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     117968.000000                         197902.000000  197902.000000
# mean           0.070129                              5.640611      51.384599
# std            0.255366                            234.071119      14.370901
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.035544      41.000000
# 50%            0.000000                              0.178480      51.000000
# 75%            0.000000                              0.582681      62.000000
# max            1.000000                          50708.000000     103.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         197902.000000  197902.000000   1.979020e+05
# mean                               0.384018       0.383791   6.873170e+03
# ...

# %%
# debt ratios are inflated by those with monthly income 0 or 1 and debt ratios in the thousands, will take debt ratio for
# those with > 100 monthly income which is still nearly 200k people 
drm = np.mean(stackt[(stackt['MonthlyIncome'].notnull()) & (stackt['MonthlyIncome'] > 100)]['DebtRatio'])

# %%
# can see from correlation matrix that numberoftimesvariables have extremely high correlation
# will pick 30-59 as it's most recent
nn = train[train['MonthlyIncome'].notnull()]
corrmat = nn.corr()
f, ax = plt.subplots(figsize = (12,9))
sns.heatmap(corrmat, square = True)

# %%
cols = list(stackt.columns)
cols.remove('NumberOfTimes90DaysLate')
cols.remove('NumberOfTime60-89DaysPastDueNotWorse')

sns.set()
sns.pairplot(stackt[cols],size = 2.5)
# Out:
# F:\Programs\Anaconda\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# F:\Programs\Anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# F:\Programs\Anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
stackt[(stackt['MonthlyIncome'].notnull()) & (stackt['MonthlyIncome'] < 100)]['MonthlyIncome']
# Out:
# test   7         0.0
#        10        0.0
#        237       0.0
#        308       0.0
#        325       0.0
#        367       0.0
#        424       0.0
#        627       0.0
#        679       0.0
#        808       0.0
#        856       0.0
#        890       0.0
#        937       0.0
#        970       0.0
#        1066      0.0
#        1076      0.0
#        1088      0.0
#        1107      1.0
#        1253      0.0
#        1331      0.0
#        1349      0.0
#        1364      1.0
#        1767      0.0
#        1841      0.0
#        1883      1.0
#        1980      0.0
#        1982      0.0
#        2099      0.0
#        2118      0.0
#        2128      0.0
#                 ...
# train  148433    0.0
#        148462    0.0
#        148472    0.0
#        148527    0.0
#        148629    0.0
#        148657    0.0
#        148674    0.0
#        148731    1.0
#        148734    0.0
#        148759    0.0
#        148760    0.0
#        148823    1.0
# ...

# %%
clean = stackt[(stackt['MonthlyIncome'].notnull()) & (stackt['MonthlyIncome'] < 100)]['DebtRatio']

# %%
stackt['MonthlyIncome'].update(clean)

# %%
stackt[(stackt['MonthlyIncome'].notnull()) & (stackt['MonthlyIncome'] < 100)]['MonthlyIncome']
# Out:
# test   7         0.0
#        10        0.0
#        237       0.0
#        308       0.0
#        325       0.0
#        367       0.0
#        424       0.0
#        627       0.0
#        679       0.0
#        808       0.0
#        856       0.0
#        890       0.0
#        937       0.0
#        970       0.0
#        1066      0.0
#        1076      0.0
#        1088      0.0
#        1107      1.0
#        1253      0.0
#        1331      0.0
#        1349      0.0
#        1364      1.0
#        1767      0.0
#        1841      0.0
#        1883      1.0
#        1980      0.0
#        1982      0.0
#        2099      0.0
#        2118      0.0
#        2128      0.0
#                 ...
# train  148433    0.0
#        148462    0.0
#        148472    0.0
#        148527    0.0
#        148629    0.0
#        148657    0.0
#        148674    0.0
#        148731    1.0
#        148734    0.0
#        148759    0.0
#        148760    0.0
#        148823    1.0
# ...

# %%
stackt
# Out:
#               SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# test  1                    NaN                              0.885519   43
#       2                    NaN                              0.463295   57
#       3                    NaN                              0.043275   59
#       4                    NaN                              0.280308   38
#       5                    NaN                              1.000000   27
#       6                    NaN                              0.509791   63
#       7                    NaN                              0.587778   50
#       8                    NaN                              0.046149   79
#       9                    NaN                              0.013527   68
#       10                   NaN                              1.000000   23
#       11                   NaN                              0.028485   37
#       12                   NaN                              0.085077   52
# ...

# %%
s = train[(train['MonthlyIncome'].notnull()) & (train['MonthlyIncome'] < 100)]['MonthlyIncome']
s
# Out:
# 15         0.0
# 45         1.0
# 51         0.0
# 74         0.0
# 91         0.0
# 168        1.0
# 196        1.0
# 218        1.0
# 299        0.0
# 327        0.0
# 401        1.0
# 422        1.0
# 509        0.0
# 538        0.0
# 606        0.0
# 630        0.0
# 637        0.0
# 711        0.0
# 768        0.0
# 792        0.0
# 842        0.0
# 845        0.0
# 984       21.0
# 1082       0.0
# 1123       0.0
# 1281       1.0
# 1354       0.0
# 1616       2.0
# 1620       0.0
# 1697       0.0
#           ...
# 148433     0.0
# 148462     0.0
# 148472     0.0
# 148527     0.0
# 148629     0.0
# 148657     0.0
# 148674     0.0
# 148731     1.0
# 148734     0.0
# 148759     0.0
# 148760     0.0
# 148823     1.0
# 148857     0.0
# 148876     7.0
# 148928     0.0
# 149064     0.0
# 149084     0.0
# 149187     0.0
# 149214     1.0
# 149289     1.0
# 149295     0.0
# 149382     1.0
# 149384     0.0
# 149463     1.0
# 149495     1.0
# 149563     0.0
# 149647     0.0
# ...

# %%
ud =train[(train['MonthlyIncome'].notnull()) & (train['MonthlyIncome'] < 100)]['DebtRatio']
ud['DebtRatioavg'] = 0.27
# Out:
# F:\Programs\Anaconda\lib\site-packages\pandas\core\series.py:1015: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc[key] = value

# %%
train['MonthlyIncome'].update(ud)
train
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                      1                              0.766127   45
# 2                      0                              0.957151   40
# 3                      0                              0.658180   38
# 4                      0                              0.233810   30
# 5                      0                              0.907239   49
# 6                      0                              0.213179   74
# 7                      0                              0.305682   57
# 8                      0                              0.754464   39
# 9                      0                              0.116951   27
# 10                     0                              0.189169   57
# 11                     0                              0.644226   30
# 12                     0                              0.018798   51
# 13                     0                              0.010352   46
# ...

# %%
train[(train['MonthlyIncome'].notnull()) & (train['MonthlyIncome'] < 100)]
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 15                     0                              0.019657   76
# 45                     0                              0.368876   68
# 51                     0                              0.818978   73
# 74                     0                              0.059669   31
# 91                     0                              0.039388   51
# 168                    0                              0.020966   29
# 196                    1                              0.025892   38
# 218                    0                              0.222696   42
# 299                    0                              0.085152   25
# 327                    0                              0.013115   43
# 401                    0                              0.134192   63
# 422                    0                              0.063514   57
# 509                    0                              1.000000   73
# ...

# %%
df2 = pd.DataFrame(ud)
df2['DR2'] = 0.27

# %%
df2
# Out:
#                  DebtRatio   DR2
# 15              477.000000  0.27
# 45             1687.500000  0.27
# 51             3095.000000  0.27
# 74             3162.000000  0.27
# 91            15466.000000  0.27
# 168             639.500000  0.27
# 196              74.500000  0.27
# 218             800.000000  0.27
# 299            1005.000000  0.27
# 327            4211.000000  0.27
# 401             926.500000  0.27
# 422            2221.500000  0.27
# 509            8500.000000  0.27
# 538             887.000000  0.27
# 606             723.000000  0.27
# 630            2866.000000  0.27
# 637              79.000000  0.27
# 711             272.000000  0.27
# 768               5.000000  0.27
# 792            2336.000000  0.27
# 842            2231.000000  0.27
# 845           11311.000000  0.27
# 984             106.272727  0.27
# 1082              0.000000  0.27
# 1123              1.000000  0.27
# 1281           1756.000000  0.27
# 1354           3278.000000  0.27
# ...
